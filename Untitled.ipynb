# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
client_df = pd.read_csv("client_data.csv")
price_df = pd.read_csv("price_data.csv")

# %%
client_df.head()
# churn refers to the rate at which customers stop doing business with a company
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  15/06/2013  15/06/2016
# 1      4660             0                0  21/08/2009  30/08/2016
# 2       544             0                0  16/04/2010  16/04/2016
# 3      1584             0                0  30/03/2010  30/03/2016
# 4      4425             0              526  13/01/2010  07/03/2016
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# ...

# %%
client_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  object
#  1   channel_sales                   14606 non-null  object
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
#  4   cons_last_month                 14606 non-null  int64
#  5   date_activ                      14606 non-null  object
#  6   date_end                        14606 non-null  object
#  7   date_modif_prod                 14606 non-null  object
#  8   date_renewal                    14606 non-null  object
#  9   forecast_cons_12m               14606 non-null  float64
#  10  forecast_cons_year              14606 non-null  int64
#  11  forecast_discount_energy        14606 non-null  int64
# ...

# %%
date_cols = ['date_activ', 'date_end', 'date_modif_prod', 'date_renewal']
for col in date_cols:
    client_df[col] = pd.to_datetime(client_df[col], errors='coerce',dayfirst=True)

# %% [markdown]
# #### No need to clean and format data as it is already done. So let's do EDA.

# %%
price_df.head()
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  01/01/2015            0.151367
# 1  038af19179925da21a25619c5a24b745  01/02/2015            0.151367
# 2  038af19179925da21a25619c5a24b745  01/03/2015            0.151367
# 3  038af19179925da21a25619c5a24b745  01/04/2015            0.149626
# 4  038af19179925da21a25619c5a24b745  01/05/2015            0.149626
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# 1             0.0                 0.0           44.266931             0.0
# 2             0.0                 0.0           44.266931             0.0
# 3             0.0                 0.0           44.266931             0.0
# 4             0.0                 0.0           44.266931             0.0
#
#    price_mid_peak_fix
# 0                 0.0
# 1                 0.0
# 2                 0.0
# ...

# %%
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193002 entries, 0 to 193001
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  193002 non-null  object
#  1   price_date          193002 non-null  object
#  2   price_off_peak_var  193002 non-null  float64
#  3   price_peak_var      193002 non-null  float64
#  4   price_mid_peak_var  193002 non-null  float64
#  5   price_off_peak_fix  193002 non-null  float64
#  6   price_peak_fix      193002 non-null  float64
#  7   price_mid_peak_fix  193002 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 11.8+ MB

# %%
client_df.hist(figsize=(15, 12), bins=30)
plt.tight_layout()
plt.show()

# %%
churn = client_df[['id', 'churn']]
churn.columns = ['Client', 'churn']
churn_total = churn.groupby(churn['churn']).count()
churn_percentage = churn_total / churn_total.sum() * 100
churn_percentage.columns = [ 'Percentage']
churn_percentage = churn_percentage.reset_index()

churn_percentage['churn'] = churn_percentage['churn'].replace({0: 'Retention', 1: 'Churn'})

plt.bar(churn_percentage['churn'],churn_percentage['Percentage'],color=['green','red'])
plt.ylabel('Percentage')
plt.title('Churn Distribution')
plt.ylim(0, 100)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# The chart paints a largely positive picture. The tall green bar, representing Retention, shows that approximately 90% of customers have remained loyal to the company. This indicates a strong and healthy customer base.
# However, the smaller red bar, representing Churn, reveals that about 10% of customers have left. While this is a minority, it represents a significant opportunity for improvement. This visual breakdown makes it immediately clear that while the company is succeeding in keeping most of its customers, there is a segment that needs attention to understand their reasons for leaving.

# %%
pd.crosstab(client_df['channel_sales'], client_df['churn'], normalize='index').plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='channel_sales'>

# %% [markdown]
# This chart illustrate

# %%
client_df['contract_length_days'] = (client_df['date_end'] - client_df['date_activ']).dt.days

# %%
client_df.head()
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month date_activ   date_end  \
# 0         0         54946                0 2013-06-15 2016-06-15
# 1      4660             0                0 2009-08-21 2016-08-30
# 2       544             0                0 2010-04-16 2016-04-16
# 3      1584             0                0 2010-03-30 2016-03-30
# 4      4425             0              526 2010-01-13 2016-03-07
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  imp_cons  \
# 0      2015-11-01   2015-06-23               0.00  ...      0.00
# ...

# %%
sns.boxplot(data=client_df, x='churn', y='contract_length_days')
# Out:
# <Axes: xlabel='churn', ylabel='contract_length_days'>

# %% [markdown]
# The key takeaway from this boxplot is that customers with longer contract durations are less likely to churn. The median and overall distribution of contract_length_days are noticeably higher for customers who remained with the service (churn = 0) compared to those who left (churn = 1). This suggests that contract length is a meaningful factor in customer retention and could be a useful predictor in a churn model.

# %%
merged_df = pd.merge(client_df, price_df, on='id', how='left')
merged_df.head()
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 2  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 3  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 4  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
#
#    cons_12m  cons_gas_12m  cons_last_month date_activ   date_end  \
# 0         0         54946                0 2013-06-15 2016-06-15
# 1         0         54946                0 2013-06-15 2016-06-15
# 2         0         54946                0 2013-06-15 2016-06-15
# 3         0         54946                0 2013-06-15 2016-06-15
# 4         0         54946                0 2013-06-15 2016-06-15
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  pow_max  churn  \
# 0      2015-11-01   2015-06-23                0.0  ...   43.648      1
# ...

# %%
numeric_df = merged_df.select_dtypes(include=['float64', 'int64'])
numeric_df.head()
# Out:
#    cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# 0         0         54946                0                0.0
# 1         0         54946                0                0.0
# 2         0         54946                0                0.0
# 3         0         54946                0                0.0
# 4         0         54946                0                0.0
#
#    forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# 0                   0                         0                     1.78
# 1                   0                         0                     1.78
# 2                   0                         0                     1.78
# 3                   0                         0                     1.78
# 4                   0                         0                     1.78
#
#    forecast_price_energy_off_peak  forecast_price_energy_peak  \
# 0                        0.114481                    0.098142
# ...

# %%
plt.figure(figsize=(15, 8))  # width=12, height=8 (in inches)
sns.heatmap(numeric_df.corr(), annot=True, fmt=".2f", cmap='coolwarm', center=0)
plt.show()

# %% [markdown]
# Insigts
# - corr between churn and contract length days is -0.07 which shows that Customers with longer contracts might be just a tiny bit less likely to churn.
# - Changing the off-peak price doesn’t seem to have any noticeable effect on whether customers leave, at least according to correlation.
# - Peak energy price changes don’t seem to have a direct, consistent link to customers leaving. Any difference in churn is so tiny that it’s probably just random variation. But the positive sign means that as the peak-period energy price increases, churn slightly increases.
# - Simillarly there is no major corelation between price and Churn

# %%
price_cols = [
    'price_off_peak_var', 'price_peak_var', 'price_mid_peak_var',
    'price_off_peak_fix', 'price_peak_fix', 'price_mid_peak_fix'
]

for col in price_cols:
    # Increased the figure size from (4,4) to (10,6)
    plt.figure(figsize=(10, 6))
    sns.boxplot(x='churn', y=col, data=merged_df)
    plt.title(f"{col} vs Churn", fontsize=16) # Increased title font size for better readability
    plt.xlabel("Churn", fontsize=12) # Added x-axis label
    plt.ylabel(col, fontsize=12) # Added y-axis label
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)
    plt.grid(True, linestyle='--', alpha=0.6) # Added a grid for better readability
    plt.show()
